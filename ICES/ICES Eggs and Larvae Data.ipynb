# %%
import os
import csv
import pandas as pd

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html
data = pd.read_table("./data/ices-eggsandlarvae/EggsAndLarvae_FullDownload.csv",
                     skiprows=1,
                     delimiter=";")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-3-4bc454cf8fca> in <module>()
#       2 data = pd.read_table("./data/ices-eggsandlarvae/EggsAndLarvae_FullDownload.csv",
#       3                      skiprows=1,
# ----> 4                      delimiter=";")
#
# ...

# %%
data
# Out:
#         ﻿ID;DateTime;Latitude;Longitude;HaulLat;HaulLon;Stage;Species;Survey;Num. counted;Length;Volume Filter Internal;Volume Filter External;Haul Num.;Sample Num.;Country;Ship;tblCodeID_Stage;tblCodeID_Survey;tblCodeID_Species;Aperture;E/W;FlowMeter Int. Calibration;FlowMeter Revs Int.;FlowMeter Ext. Calibration;FlowMeter Revs Ext.;Water Depth;Max Sampling Depth;Haul Depth;Haul Duration;NoMeas;MeasYolk;TotMeas;Caught;CaugYolk;TotCaug;TotPerm2;AbSmall;AbMedium;AbLarge;AbYolk;Area-code;Period;Sampling Period;Temp max sampler depth;ICES Rec. Code;Agency/Person;Ship/Person;Cruise Number;Original SampleID;Station Number;Series Number;Wire Out;Meta;Primary Reference;Secondary Reference;Num. of Myomeres;Gear Submited;Gear;Net Opening;Wind Dir;Temperature at surface;Temperature at 20m;Temperature at 50m;Temperature at 100m;Sub factor;Salinity;Salinity at 20m;Bottom salinity;DayNight;Statrec;haulval;bycspecreccode;stdspecreccode;speedwater;winddir;windspeed;thermocline;thclinedepth;Gear cou
# ...
